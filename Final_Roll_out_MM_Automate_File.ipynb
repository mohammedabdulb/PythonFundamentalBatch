# %%
import pandas as pd
read_xlsx1 = pd.read_excel("C:\\Users\\mohd.abdul.basith.DIR\\OneDrive - Accenture\\Desktop\\checking PIR Data\\Daya Sync test for MM\\18th June SFDC MM Data Ext.xlsx",usecols = "A,C,D")
read_MARC_18th_June = pd.read_excel("C:\\Users\\mohd.abdul.basith.DIR\\OneDrive - Accenture\\Desktop\\checking PIR Data\\Daya Sync test for MM\\Copy MARC JUNE 18.xlsx")
read_MAKT_18th_June = pd.read_excel("C:\\Users\\mohd.abdul.basith.DIR\\OneDrive - Accenture\\Desktop\\checking PIR Data\\Daya Sync test for MM\\Copy MAKT JUNE 18.xlsx")
read_MARA_18th_June = pd.read_excel("C:\\Users\\mohd.abdul.basith.DIR\\OneDrive - Accenture\\Desktop\\checking PIR Data\\Daya Sync test for MM\\Copy MARA JUNE 18.xlsx")
read_MBEW_18th_June = pd.read_excel("C:\\Users\\mohd.abdul.basith.DIR\\OneDrive - Accenture\\Desktop\\checking PIR Data\\Daya Sync test for MM\\Copy MBEW JUNE 18.xlsx")
read_MAKT_18th_June.fillna('abc#NA',inplace = True)
read_MARA_18th_June.fillna('abc#NA',inplace = True)
read_MBEW_18th_June.fillna('abc#NA',inplace = True)
read_MARC_18th_June.fillna('abc#NA',inplace = True)
SFDC_MM_dict=dict(zip(read_xlsx1['MATNR__c'].astype(str)+read_xlsx1['WERKS__c'], read_xlsx1['Id'])) # Correct one
for key in SFDC_MM_dict.keys():
    print(key,SFDC_MM_dict[key])
    break

unique_id_list = read_xlsx1['Id'].to_list()

new_df = pd.DataFrame(columns=['Id','Name','ZEINR__c','MATNR__c','Material_group_code__c','WERKS__c','MEINS__c','Description__c',
                               'Jan_Code__c','MFRNR__c','MFRPN__c','MTART__c','MMSpecialGL__c','MmSpecialTaxCode__c','BSTME__c',
                               'ProfitCenter__c','EKGRP__c','SAP_GL_Code__c','PRCTR__c','SAP_Tax_Code__c','Size__c','LGORT__c','BKLAS__c',
                               'Del flag'],index = range(0,30000))
							   
#this is for Salesforce and MARC
base_for_loop_count=0
for ind in read_MARC_18th_June.index:
    #print(ind,read_xlsx1['Purchasing Info Rec.'][ind] )
    count=0
    base_for_loop_count+=1
    a = read_MARC_18th_June['Material'][ind].astype(str)+read_MARC_18th_June['Plant'][ind]
    print(' base_for_loop_count == is==',base_for_loop_count)
    for key in SFDC_MM_dict.keys():
        count += 1
        if( key == a ):
            print('insdie for loop Row Number is SFDC EXt is===>',count)
            new_df['Id'][ind]=SFDC_MM_dict[key]
            break
    new_df['MATNR__c'][ind]       =read_MARC_18th_June['Material'][ind]
    new_df['WERKS__c'][ind]       =read_MARC_18th_June['Plant'][ind]
    new_df['EKGRP__c'][ind]       =read_MARC_18th_June['Purchasing Group'][ind]
    new_df['ProfitCenter__c'][ind]=read_MARC_18th_June['Profit Center'][ind]
    new_df['PRCTR__c'][ind]       =read_MARC_18th_June['Profit Center'][ind]
    new_df['LGORT__c'][ind]       =read_MARC_18th_June['Storage loc. for EP'][ind]
    new_df['Del flag'][ind]       =read_MARC_18th_June['DF at plant level'][ind]
    new_df['MMSpecialGL__c'][ind] ='False'

MBEW_MM_dict=dict(zip(read_MBEW_18th_June['Material'].astype(str)+read_MBEW_18th_June['Valuation Area'], read_MBEW_18th_June['Valuation Class'])) # Correct one
for key in MBEW_MM_dict.keys():
    print(key,MBEW_MM_dict[key])
    break

#this is for MBEW
base_for_loop_count=0
count=0
for ind in read_MARC_18th_June.index:
    #print(ind,read_xlsx1['Purchasing Info Rec.'][ind] )
    
    base_for_loop_count+=1
    a = read_MARC_18th_June['Material'][ind].astype(str)+read_MARC_18th_June['Plant'][ind]
    #print(' base_for_loop_count == is==',base_for_loop_count)
    for key in MBEW_MM_dict.keys():
        if( key == a ):
            count += 1
            print('insdie for loop Row Number is SFDC EXt is===>',count)
            new_df['BKLAS__c'][ind]=MBEW_MM_dict[key]
            break
# New block of code

#Here key cant be used because n number of values we have to fetch.
MARA_MM_list=read_MARA_18th_June['Material'].to_list() # Correct one
for index in MARA_MM_list:
    print(index)
	
	
#this is for MARA
count = 0
for ind in read_MARC_18th_June.index:
    #print(ind,read_xlsx1['Purchasing Info Rec.'][ind] )
    
    base_for_loop_count+=1
    a = read_MARC_18th_June['Material'][ind]
    #print(' base_for_loop_count == is==',base_for_loop_count)
    abc_test_for_fast = 0
    for check in MARA_MM_list:
        if( check == a ):
            count += 1
            print('insdie for loop Row Number is SFDC EXt is===> count ',count,check,'abc_test_for_fast',abc_test_for_fast)
            print(f"Size/dimensions at row number {abc_test_for_fast} {read_MARA_18th_June['Size/dimensions'][abc_test_for_fast] }")
            print(read_MARA_18th_June['Base Unit of Measure'][abc_test_for_fast])
            new_df['Size__c'][ind]=read_MARA_18th_June['Size/dimensions'][abc_test_for_fast]
            new_df['BSTME__c'][ind]=read_MARA_18th_June['Base Unit of Measure'][abc_test_for_fast]
            new_df['MTART__c'][ind]=read_MARA_18th_June['Material Type'][abc_test_for_fast]
            new_df['MFRPN__c'][ind]=read_MARA_18th_June['Manufacturer Part No.'][abc_test_for_fast]    
            new_df['MFRNR__c'][ind]=read_MARA_18th_June['Manufacturer'][abc_test_for_fast]
            new_df['Jan_Code__c'][ind]=read_MARA_18th_June['EAN/UPC'][abc_test_for_fast]
            new_df['MEINS__c'][ind]=read_MARA_18th_June['Base Unit of Measure'][abc_test_for_fast]
            new_df['Material_group_code__c'][ind]=read_MARA_18th_June['Material Group'][abc_test_for_fast]
            new_df['ZEINR__c'][ind]=read_MARA_18th_June['Document'][abc_test_for_fast]
            break
        abc_test_for_fast +=1
		

#Here key cant be used because n number of values we have to fetch.
MAKT_MM_list=read_MAKT_18th_June['Material'].to_list() # Correct one
for index in MAKT_MM_list:
    print(index)
	
	
#this is for MAKT
count = 0
for ind in read_MARC_18th_June.index:
    #print(ind,read_xlsx1['Purchasing Info Rec.'][ind] )
    
    base_for_loop_count+=1
    a = read_MARC_18th_June['Material'][ind]
    #print('a is ',a , 'type of a',type(a))
    #print(read_MARC_18th_June['Material'][ind],type(read_MARC_18th_June['Material'][ind]))
    abc_test_for_fast = 0
    for check in MAKT_MM_list:
        #print(type(check),check)
        #print('check is ',check)
        if( check == a ):
            count += 1
            print('insdie for loop Row Number is SFDC EXt is===> count ',count,check,'abc_test_for_fast',abc_test_for_fast,read_MAKT_18th_June['Material Description'][abc_test_for_fast])
            #print(f"Size/dimensions at row number {abc_test_for_fast} {read_MAKT_18th_June['Material Description'][abc_test_for_fast] }")
            #print(read_MARA_18th_June['Base Unit of Measure'][abc_test_for_fast])
            new_df['Name'][ind]=read_MAKT_18th_June['Material Description'][abc_test_for_fast]
            new_df['Description__c'][ind]=read_MAKT_18th_June['Material Description'][abc_test_for_fast]
            break
        abc_test_for_fast +=1
        #print('check')
		

print(read_MAKT_18th_June['Material Description'][1689])
new_df = new_df.replace(['abc#NA'],'')


temp_prepare = pd.ExcelWriter('C:\\Users\\mohd.abdul.basith.DIR\\OneDrive - Accenture\\Desktop\\checking PIR Data\\Daya Sync test for MM\\Newly Created file 05 28.xlsx')
# write dataframe to excel sheet named 'marks'
new_df.to_excel(temp_prepare, 'TEMPLATE_05_28_pm')
# save the excel file
temp_prepare.save()
# Out:
# 100000000000898J318 a7U10000000DdNqEAK
#  base_for_loop_count == is== 1
# insdie for loop Row Number is SFDC EXt is===> 1
#  base_for_loop_count == is== 2
# insdie for loop Row Number is SFDC EXt is===> 200301
#  base_for_loop_count == is== 3
# insdie for loop Row Number is SFDC EXt is===> 241331
#  base_for_loop_count == is== 4
# insdie for loop Row Number is SFDC EXt is===> 14121
#  base_for_loop_count == is== 5
# insdie for loop Row Number is SFDC EXt is===> 215991
#  base_for_loop_count == is== 6
# insdie for loop Row Number is SFDC EXt is===> 215992
#  base_for_loop_count == is== 7
# insdie for loop Row Number is SFDC EXt is===> 207732
#  base_for_loop_count == is== 8
# insdie for loop Row Number is SFDC EXt is===> 207733
#  base_for_loop_count == is== 9
# insdie for loop Row Number is SFDC EXt is===> 207734
#  base_for_loop_count == is== 10
# insdie for loop Row Number is SFDC EXt is===> 208443
#  base_for_loop_count == is== 11
# ...
